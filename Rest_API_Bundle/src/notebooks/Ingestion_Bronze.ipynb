# %% [markdown]
# Fetch the data

# %%
import requests
import json

url = "https://dummyjson.com/products"

response = requests.get(url)

# Store JSON response
data = response.json()

# Write to Bronze
dbutils.fs.put(
    "/Volumes/project_dev/bronze/products/products.json",
    json.dumps(data),
    overwrite=True
)
